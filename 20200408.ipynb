# %% [markdown]
# # ECG-ViEW

# %%
import pandas as pd
import numpy as np
import pylab as plt

#Visualization Libraries
import seaborn as sns

# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(10, 5))
# Size of matplotlib histogram bins
bin_size = 40

# %% [markdown]
# ## 1. ECG data processing

# %%
df_one = pd.read_csv('Electrocardiogram.csv')
df_one.head()
# Out:
#    personid              ecgdate ecgdept ecgsource     RR     PR   QRS   QT  \
# 0    120971  2006-05-23 09:57:00       H         M  952.0    NaN   NaN  388
# 1    120971  2012-04-19 08:09:06       H         E  750.0  140.0  84.0  360
# 2       270  2004-07-03 09:05:13       O         M  600.0  122.0  78.0  318
# 3    306709  2013-04-06 22:10:16       E         M  577.0  150.0  92.0  362
# 4     87768  1997-12-17 11:11:26       O         M  698.0  136.0  88.0  354
#
#    QTc  P_wave_axis  QRS_axis  T_wave_axis  ACCI
# 0  397          NaN       NaN          NaN     9
# 1  415          NaN       NaN          NaN     9
# 2  410         62.0      86.0         61.0     7
# 3  476         17.0      46.0         70.0    12
# 4  423         28.0      59.0         29.0     3

# %%
df_one.shape
# Out:
# (979273, 13)

# %%
df_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979273 entries, 0 to 979272
# Data columns (total 13 columns):
# personid       979273 non-null int64
# ecgdate        979273 non-null object
# ecgdept        979273 non-null object
# ecgsource      979273 non-null object
# RR             979239 non-null float64
# PR             774260 non-null float64
# QRS            810373 non-null float64
# QT             979273 non-null int64
# QTc            979273 non-null int64
# P_wave_axis    732827 non-null float64
# QRS_axis       762274 non-null float64
# T_wave_axis    762248 non-null float64
# ACCI           979273 non-null int64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 97.1+ MB

# %%
df_one.describe()
# Out:
#             personid             RR             PR            QRS  \
# count  979273.000000  979239.000000  774260.000000  810373.000000
# mean   231021.688946     851.683240     157.081364      91.061474
# std    133238.981417     196.989159      26.661289      15.149489
# min         1.000000     204.000000      36.000000       2.000000
# 25%    115711.000000     732.000000     140.000000      82.000000
# 50%    231037.000000     857.000000     156.000000      88.000000
# 75%    346411.000000     968.000000     172.000000      98.000000
# max    461795.000000   30000.000000    1738.000000     380.000000
#
#                   QT            QTc    P_wave_axis       QRS_axis  \
# count  979273.000000  979273.000000  732827.000000  762274.000000
# mean      389.997336     425.415081      48.357848      45.215670
# std        43.490019      31.493654      24.848064      38.048566
# min        70.000000      53.000000     -89.000000     -89.000000
# 25%       364.000000     405.000000      36.000000      22.000000
# 50%       390.000000     420.000000      52.000000      51.000000
# 75%       416.000000     440.000000      65.000000      71.000000
# max       852.000000     878.000000     270.000000     270.000000
#
#          T_wave_axis           ACCI
# count  762248.000000  979273.000000
# mean       46.198097       7.580933
# std        38.416339       3.062956
# min       -89.000000       0.000000
# 25%        28.000000       6.000000
# 50%        44.000000       8.000000
# 75%        59.000000      10.000000
# max       270.000000      23.000000

# %%
df_one = df_one.sort_values('ecgdate').drop_duplicates('personid',keep='last')
df_one.shape
# Out:
# (461034, 13)

# %%
df_one.dtypes
# Out:
# personid         int64
# ecgdate         object
# ecgdept         object
# ecgsource       object
# RR             float64
# PR             float64
# QRS            float64
# QT               int64
# QTc              int64
# P_wave_axis    float64
# QRS_axis       float64
# T_wave_axis    float64
# ACCI             int64
# dtype: object

# %%
fig = plt.figure(figsize = (15,15))
fig_dim = (4,3)

plt.subplot2grid(fig_dim, (0,0))
df_one['ecgdept'].value_counts().plot(kind='bar', title='ECG Department')

plt.subplot2grid(fig_dim, (0,1))
df_one['ecgsource'].value_counts().plot(kind='bar', title='ECG Source')

plt.subplot2grid(fig_dim, (0,2))
df_one['ACCI'].value_counts().plot(kind='bar', title='ACCI')

plt.subplot2grid(fig_dim, (1,0))
df_one['RR'].hist(bins=50)
plt.title('RR')

plt.subplot2grid(fig_dim, (1,1))
df_one['PR'].hist(bins=50)
plt.title('PR')

plt.subplot2grid(fig_dim, (1,2))
df_one['QRS'].hist(bins=50)
plt.title('QRS')

plt.subplot2grid(fig_dim, (2,0))
df_one['QT'].hist(bins=50)
plt.title('QT')

plt.subplot2grid(fig_dim, (2,1))
df_one['QTc'].hist(bins=50)
plt.title('QTc')

plt.subplot2grid(fig_dim, (2,2))
df_one['P_wave_axis'].hist(bins=50)
plt.title('P wave axis')

plt.subplot2grid(fig_dim, (3,0))
df_one['QRS_axis'].hist(bins=50)
plt.title('QRS axis')

plt.subplot2grid(fig_dim, (3,1))
df_one['T_wave_axis'].hist(bins=50)
plt.title('T wave axis')
# Out:
# Text(0.5, 1.0, 'T wave axis')

# %%
df_one.isnull().sum()
# Out:
# personid            0
# ecgdate             0
# ecgdept             0
# ecgsource           0
# RR                 23
# PR              63805
# QRS             54727
# QT                  0
# QTc                 0
# P_wave_axis    100027
# QRS_axis        92518
# T_wave_axis     92521
# ACCI                0
# dtype: int64

# %%
# Drop instances that have missing values 
df_two = df_one.dropna(subset=['RR', 'PR', 'QRS', 'P_wave_axis','QRS_axis', 'T_wave_axis']);

# %%
df_two.isnull().sum()
# Out:
# personid       0
# ecgdate        0
# ecgdept        0
# ecgsource      0
# RR             0
# PR             0
# QRS            0
# QT             0
# QTc            0
# P_wave_axis    0
# QRS_axis       0
# T_wave_axis    0
# ACCI           0
# dtype: int64

# %%
df_two.shape
# Out:
# (359497, 13)

# %%
# Drop unrelevant information 
df_three = df_two.drop(columns = ['ecgdate', 'ecgsource', 'ecgdept'])

# %%
df_three.head()
# Out:
#         personid      RR     PR   QRS   QT  QTc  P_wave_axis  QRS_axis  \
# 970189     62646   594.0  134.0  88.0  326  422         42.0     -57.0
# 936960    225177   625.0  138.0  84.0  362  457         70.0      26.0
# 757784    100620   674.0  152.0  96.0  412  501         57.0      64.0
# 785324    391047  1053.0  184.0  88.0  388  377         67.0      73.0
# 877940    458019   909.0  132.0  92.0  400  419         29.0      63.0
#
#         T_wave_axis  ACCI
# 970189         52.0     2
# 936960         63.0     1
# 757784         41.0     0
# 785324         48.0     0
# 877940         53.0     0

# %% [markdown]
# ## 2. Diagnosis code & personal info (sex)

# %%
df_diag_one = pd.read_csv('Diagnosis.csv')
df_diag_one.head()
# Out:
#    personid        diagdate diagcode diaglocalcode diagdept
# 0    141778   6/4/1997 0:00    L73.8       DC12467        O
# 1    141778   6/7/1997 0:00    L73.8       DC12467        O
# 2    141778  6/16/1997 0:00    L73.8       DC12467        O
# 3    141778  6/23/1997 0:00    L73.8       DC12467        O
# 4    141778  6/30/1997 0:00    L73.8       DC12467        O

# %%
df_diag_one.shape
# Out:
# (1048575, 5)

# %%
# Drop duplicate entries (repeated entry of the same ID)
df_diag_two = df_diag_one.sort_values('diagdate').drop_duplicates('personid',keep='last')
df_diag_two.sort_values(by=['personid'])
# Out:
#          personid         diagdate diagcode diaglocalcode diagdept
# 673127          7   6/21/2002 0:00    K05.3        DC3060        O
# 338532         12   6/29/2000 0:00    R07.4        DC7933        O
# 994758         24    4/1/2005 0:00    G43.9       DC12570        O
# 288805         30   9/29/2003 0:00   H66.9C       DC14257        O
# 1012578        46  11/14/2001 0:00      C73        DC4775        O
# 999910         61    5/3/1997 0:00    K21.9        DC1091        O
# 995053         63    6/7/1997 0:00    L40.0        DC9006        O
# 808966         65   4/22/2002 0:00    K29.5        DC2704        O
# 735901         73    2/1/2006 0:00    J34.2        DC5890        O
# 1013905        94   9/18/2001 0:00    I08.9       DC14388        O
# 623696        129    9/8/1998 0:00    K73.9        DC3821        O
# 449496        152   6/26/1995 0:00    H66.3        DC2454        O
# 1024228       155    2/6/1998 0:00   H04.1B          DC98        O
# 463846        175   9/23/2003 0:00    Z03.9        DC6671        O
# 50300         192   9/30/1998 0:00    E11.3        DC2827        O
# 986811        202    4/4/2007 0:00    F32.9       DC13525        O
# 616240        203   9/19/2001 0:00      I10        DC1255        O
# 967814        225   12/3/2003 0:00    D64.9        DC1231        O
# 608991        226    9/7/2005 0:00    I20.0        DC9026        O
# 727166        246    1/8/2000 6:11    H81.3        DC1529        E
# 1014415       275    9/7/1999 0:00    F41.9        DC3009        O
# 703721        289   9/22/1999 0:00    N95.1        DC4780        O
# 771689        310   4/16/2004 0:00    Z03.9        DC6671        O
# 328272        324   3/14/2007 0:00    L20.9       DC14434        O
# 863720        330    1/7/2002 0:00   R94.3A        DC6541        O
# 727688        333   9/17/2001 0:00    I21.9       DC13972        O
# 713454        348   6/30/2005 0:00    D12.6       DC12048        O
# 738679        356   9/26/2002 0:00    B18.1        DC4883        O
# 607020        391    8/8/2001 0:00    E66.9        DC3836        O
# 275555        394    3/8/2004 0:00    R00.2        DC7335        O
# ...           ...              ...      ...           ...      ...
# 612609     461296   11/3/2006 0:00    C50.9       DC14481        O
# 556289     461313   9/30/2002 0:00    K76.0        DC2137        O
# 339412     461322   9/30/2003 0:00    H81.3        DC1529        O
# 724334     461345    9/5/2005 0:00    Z00.0          DC55        O
# 883304     461347    9/8/2004 0:00    F43.9       DC14713        O
# 378368     461353   4/25/2007 0:00    E11.9        DC4314        O
# 738190     461385   9/19/2001 0:00    K26.9        DC7203        O
# 60310      461393   7/28/2004 0:00   M81.99        DC3766        O
# 280577     461410   9/30/1999 0:00   S82.40        DC1885        O
# 484199     461419   4/20/1998 0:00      J42       DC13881        O
# 475999     461425    7/3/2002 0:00    H73.0        DC2045        O
# 465622     461468   9/16/2004 0:00    B18.2        DC3684        O
# 527790     461505    9/6/2002 0:00      D34        DC3227        O
# 1025767    461517    4/3/2001 0:00    F45.9       DC10009        O
# 746534     461537   7/27/1998 0:00    J35.0       DC12982        O
# 881453     461542    6/7/2000 0:00      N72        DC6709        O
# 1028497    461546    6/5/1997 0:00    M35.2       DC13775        O
# 490176     461613    8/9/2006 0:00      R53        DC3125        O
# 940621     461667   9/29/2006 0:00      I10        DC1255        O
# 835577     461670   4/30/2007 0:00      I10        DC1255        O
# 627366     461673    6/1/1995 0:00    B02.9       DC13111        O
# 446066     461701   4/24/2001 0:00      R05        DC4353        O
# 554431     461707  12/28/1999 0:00   M24.29        DC7983        O
# 124769     461719    9/8/1998 0:00    R60.9       DC13220        O
# 1018383    461726   9/6/2002 10:50    K59.9       DC12932        E
# 1018262    461731    3/3/1999 0:00    J32.0        DC8922        O
# 675620     461733    8/8/2003 0:00    M51.1         DC314        O
# 289428     461743    8/9/2003 0:00    E14.9        DC6452        O
# 242695     461751    9/7/2002 0:00    H40.1       DC11344        O
# 563760     461794    7/4/2002 0:00   M99623        DC2152        O
#
# [33821 rows x 5 columns]

# %%
df_diag_two.shape
# Out:
# (33821, 5)

# %%
df_person = pd.read_csv('Person.csv')
df_person.head()
# Out:
#    personid  sex  Birthyeargroup  ethnicity
# 0    369485    1              16          1
# 1    138392    0              14          1
# 2    188469    1              20          1
# 3    169164    0              12          1
# 4    434516    1              14          1

# %%
df_person.shape
# Out:
# (461034, 4)

# %%
# Merge the diagnosis dataset with the personal info dataset with the common column (personid)
df_diag_person = pd.merge(df_diag_two, df_person, on='personid')

# %%
df_diag_person.head()
# Out:
#    personid         diagdate diagcode diaglocalcode diagdept  sex  \
# 0    125349    1/1/2005 9:06    K35.9        DC9833        E    1
# 1    331354  1/10/1996 15:02    M30.3        DC5242        E    1
# 2    305626  1/10/1996 17:53    R06.0        DC8864        E    1
# 3    388717   1/10/2001 0:00    K83.8        DC6424        O    1
# 4     43398   1/10/2001 0:00    K29.0        DC7463        O    1
#
#    Birthyeargroup  ethnicity
# 0              10          1
# 1              20          1
# 2               7          1
# 3               9          1
# 4              13          1

# %%
df_diag_person.shape
# Out:
# (33821, 8)

# %%
df_diag_person.isnull().sum()
# Out:
# personid          0
# diagdate          0
# diagcode          0
# diaglocalcode     0
# diagdept          0
# sex               0
# Birthyeargroup    0
# ethnicity         0
# dtype: int64

# %%
####################### Create a new feature base on the diagnosis code: MI (1 = MI, 0 = no)
condition = (df_diag_person['diaglocalcode']=='DC5624')|(df_diag_person['diaglocalcode']=='DC7547')|(df_diag_person['diaglocalcode']=='DC8877')|(df_diag_person['diaglocalcode']=='DC910')|(df_diag_person['diaglocalcode']=='DC967')|(df_diag_person['diaglocalcode']=='DC13972')|(df_diag_person['diaglocalcode']=='DC14546')

df_diag_person['MI'] = np.where(condition, '1', '0')
df_diag_person.head()
# Out:
#    personid         diagdate diagcode diaglocalcode diagdept  sex  \
# 0    125349    1/1/2005 9:06    K35.9        DC9833        E    1
# 1    331354  1/10/1996 15:02    M30.3        DC5242        E    1
# 2    305626  1/10/1996 17:53    R06.0        DC8864        E    1
# 3    388717   1/10/2001 0:00    K83.8        DC6424        O    1
# 4     43398   1/10/2001 0:00    K29.0        DC7463        O    1
#
#    Birthyeargroup  ethnicity MI
# 0              10          1  0
# 1              20          1  0
# 2               7          1  0
# 3               9          1  0
# 4              13          1  0

# %%
# Check the number of entries of a specific diagnostic code 
df_diag_person['diaglocalcode'][df_diag_person['diaglocalcode'] == "DC14546"].value_counts()
# Out:
# DC14546    1
# Name: diaglocalcode, dtype: int64

# %%
df_diag_person['diaglocalcode'].value_counts()
# Out:
# DC6671     1420
# DC1255     1263
# DC7933      902
# DC5551      472
# DC8933      365
# DC4314      326
# DC4187      321
# DC4317      295
# DC4780      279
# DC12982     264
# DC12200     260
# DC3836      255
# DC14048     251
# DC14257     250
# DC3049      247
# DC6541      247
# DC7938      225
# DC55        215
# DC7335      211
# DC724       207
# DC2459      206
# DC12704     200
# DC3877      198
# DC2704      197
# DC8922      193
# DC8367      190
# DC2137      190
# DC7860      189
# DC3766      187
# DC8131      181
#            ...
# DC8451        1
# DC10412       1
# DC12796       1
# DC10731       1
# DC7258        1
# DC7310        1
# DC12656       1
# DC4300        1
# DC10750       1
# DC9064        1
# DC14740       1
# DC7519        1
# DC5975        1
# DC5243        1
# DC9445        1
# DC14094       1
# DC426         1
# DC7476        1
# DC10661       1
# DC9423        1
# DC10610       1
# DC4209        1
# DC9892        1
# DC13432       1
# DC7834        1
# DC9806        1
# DC12406       1
# DC8334        1
# DC2254        1
# DC788         1
# Name: diaglocalcode, Length: 2572, dtype: int64

# %%
df_diag_person['MI'].value_counts()
# Out:
# 0    33670
# 1      151
# Name: MI, dtype: int64

# %%
df_diag_person['MI'].value_counts().plot(kind='bar', title='MI Count')

# %%
df_diag_person.head()
# Out:
#    personid         diagdate diagcode diaglocalcode diagdept  sex  \
# 0    125349    1/1/2005 9:06    K35.9        DC9833        E    1
# 1    331354  1/10/1996 15:02    M30.3        DC5242        E    1
# 2    305626  1/10/1996 17:53    R06.0        DC8864        E    1
# 3    388717   1/10/2001 0:00    K83.8        DC6424        O    1
# 4     43398   1/10/2001 0:00    K29.0        DC7463        O    1
#
#    Birthyeargroup  ethnicity MI
# 0              10          1  0
# 1              20          1  0
# 2               7          1  0
# 3               9          1  0
# 4              13          1  0

# %% [markdown]
# ## 3. Merge to obtain the final dataset

# %%
# Merge the ecg dataset with the combined diagnosis/personal info dataset with the common column (personid)
df_1 = pd.merge(df_three, df_diag_person, on='personid')
df_1
# Out:
#        personid      RR     PR    QRS   QT  QTc  P_wave_axis  QRS_axis  \
# 0        304289  1111.0  126.0   92.0  436  413         72.0      67.0
# 1        178604   896.0  138.0   86.0  380  401         28.0      20.0
# 2        140895   952.0  176.0   96.0  416  426         28.0      -2.0
# 3        168032  1200.0  180.0  120.0  452  412         52.0      70.0
# 4         47257  1277.0  164.0  136.0  488  431         51.0      28.0
# 5        428357  1034.0  152.0   88.0  432  424         70.0      77.0
# 6         21712   800.0  164.0   70.0  374  417         62.0       7.0
# 7        441349   870.0  144.0   84.0  376  403         16.0      -6.0
# 8        379901   896.0  172.0  104.0  400  422         41.0      87.0
# 9         69291   800.0  156.0   76.0  400  447         21.0      30.0
# 10       172627   845.0  124.0   76.0  394  428         27.0      80.0
# 11       181443   741.0  154.0   84.0  344  399         51.0      69.0
# 12       307375   811.0  124.0   94.0  368  408         35.0      52.0
# 13       328144   420.0  148.0   74.0  262  404         46.0      83.0
# 14        45174  1071.0  184.0   88.0  432  417         65.0      84.0
# 15        42891  1071.0  142.0   96.0  422  407         18.0      69.0
# 16       182934   632.0  170.0   84.0  316  397         56.0     -11.0
# 17        15927  1017.0  202.0  106.0  430  425         10.0       3.0
# 18       254528  1017.0  144.0  100.0  408  404         35.0      38.0
# 19       138754   759.0  170.0   82.0  366  419         55.0      47.0
# 20         7802   909.0  124.0   86.0  376  394          4.0      63.0
# 21       250914   984.0  196.0   84.0  392  394         69.0      70.0
# 22        33770   741.0  132.0   84.0  392  455         -4.0      58.0
# 23       446887   811.0  142.0   82.0  360  399         75.0      68.0
# 24       191211   968.0  136.0  142.0  408  414         60.0      93.0
# 25          979  1091.0  152.0   98.0  408  390         40.0      43.0
# 26       246704   556.0  150.0   72.0  300  402         57.0       2.0
# 27       143850   896.0  154.0   82.0  350  369         71.0      71.0
# 28       198592   390.0  100.0   50.0  268  429        173.0      79.0
# 29       424191   632.0  148.0   90.0  334  419         49.0      74.0
# ...         ...     ...    ...    ...  ...  ...          ...       ...
# 26955    364800   938.0  184.0  106.0  406  418         60.0      62.0
# 26956    213870   698.0  128.0  102.0  354  423         69.0      36.0
# 26957    237090  1017.0  158.0   78.0  418  413         30.0      31.0
# 26958    359760   833.0  154.0   80.0  396  433         51.0      28.0
# 26959    238463  1176.0  222.0   92.0  452  416         39.0      27.0
# 26960    403644   723.0  168.0   96.0  358  420         56.0      42.0
# 26961    326110   769.0  152.0   86.0  374  426         62.0      69.0
# 26962    156199   896.0  168.0   90.0  364  384         71.0      36.0
# 26963    244376   984.0  210.0  110.0  400  402         73.0     107.0
# 26964     16405   750.0  140.0  110.0  402  463         49.0      90.0
# 26965    284108   870.0  138.0   96.0  402  430         65.0      63.0
# 22       0              10          1  0
# 23       1              17          1  0
# 24       1               9          1  0
# 25       1              14          1  0
# 26       1              19          1  0
# 27       1              12          1  0
# 28       1              21          1  0
# 29       1              11          1  0
# ...    ...             ...        ... ..
# 26955    1              10          1  0
# 26956    1              20          1  0
# 26957    1              10          1  0
# 26958    0              12          1  0
# 26959    1              14          1  0
# 26960    0              15          1  0
# 26961    0              14          1  0
# 26962    0              19          1  0
# 26963    1              20          1  0
# 26964    0              19          1  0
# 26965    0              13          1  0
# 26966    0              10          1  0
# 26967    1              12          1  1
# 26968    1              14          1  0
# 26969    0               8          1  0
# 26970    0              12          1  0
# 26971    0              14          1  0
# 26972    1              15          1  0
# 26973    1              10          1  0
# 26974    1              11          1  0
# 26975    1              14          1  0
# 26976    0              10          1  0
# 26977    1              20          1  0
# 26978    1              10          1  0
# 26979    0               7          1  0
# 26980    0              13          1  0
# 26981    0              12          1  0
# 26982    0              13          1  0
# 26983    0              11          1  0
# 26984    1               7          1  0
#
# [26985 rows x 18 columns]

# %%
df_2 = df_1.drop(columns = ['diagdate', 'diagcode', 'diaglocalcode','diagdept', 'personid', 'ethnicity'])
df_2.head()
# Out:
#        RR     PR    QRS   QT  QTc  P_wave_axis  QRS_axis  T_wave_axis  ACCI  \
# 0  1111.0  126.0   92.0  436  413         72.0      67.0         40.0     1
# 1   896.0  138.0   86.0  380  401         28.0      20.0         46.0     3
# 2   952.0  176.0   96.0  416  426         28.0      -2.0         24.0     2
# 3  1200.0  180.0  120.0  452  412         52.0      70.0         35.0     0
# 4  1277.0  164.0  136.0  488  431         51.0      28.0         54.0     3
#
#    sex  Birthyeargroup MI
# 0    0              11  0
# 1    1               8  0
# 2    0              10  0
# 3    1              14  0
# 4    1               7  0

# %%
df_2['Birthyeargroup'].value_counts()
# Out:
# 14    3357
# 13    3334
# 12    2629
# 15    2451
# 10    2450
# 11    2400
# 9     2337
# 8     1584
# 16    1321
# 20    1243
# 7      883
# 17     748
# 19     666
# 18     527
# 6      483
# 21     373
# 5      161
# 4       32
# 3        5
# 0        1
# Name: Birthyeargroup, dtype: int64

# %%
df_2.shape
# Out:
# (26985, 12)

# %%
df_2['MI'].value_counts()
# Out:
# 0    26862
# 1      123
# Name: MI, dtype: int64

# %%
# Created a correlation matrix
correlation_matrix = df_2.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# ## 4. Split train and test data

# %%
train_data = df_2.values
train_data.shape
# Out:
# (26985, 12)

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split

# Training data features
train_features = train_data[:, 0:11]

# 'MI' column values
train_target = train_data[:, 11]

# Split 80-20 train vs test data
train_x, test_x, train_y, test_y = train_test_split(train_features, 
                                                    train_target, 
                                                    test_size=0.20, 
                                                    random_state=0,
                                                    shuffle=True)

print (train_features.shape, train_target.shape)
print (train_x.shape, train_y.shape)
print (test_x.shape, test_y.shape)
# Out:
# (26985, 11) (26985,)
# (21588, 11) (21588,)
# (5397, 11) (5397,)

# %%
unique, counts = np.unique(train_y, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'0': 21481, '1': 107}

# %%
unique, counts = np.unique(test_y, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'0': 5381, '1': 16}

# %% [markdown]
# ## 5. Support Vector Machine

# %%
from sklearn import svm
clf_svm = svm.SVC(gamma = 'auto', kernel = 'sigmoid')
clf_svm.fit(train_x, train_y)
ypred = clf_svm.predict(train_x)

# %%
x_idx = np.arange(train_x.shape[0])

plt.plot(x_idx, ypred, 'mo', x_idx, train_y, 'b.',alpha=.3);
plt.title('Support Vector Machine, (0:dead, 1:survive) \
          \n Blue: actual data (ground truth), Red: predicted values');

# %%
predict_y = clf_svm.predict(test_x)
confusion_matrix = metrics.confusion_matrix(test_y, predict_y)

print ("Confusion Matrix ", confusion_matrix)

print ("          Predicted")
print ("         |   0  |   1  |")
print ("         |------|------|")
print ("       0 | %3d |  %3d |" % (confusion_matrix[0, 0],
                                   confusion_matrix[0, 1]))
print ("Actual   |------|------|")
print ("       1 |  %3d |  %3d |" % (confusion_matrix[1, 0],
                                   confusion_matrix[1, 1]))
print ("         |------|------|")
# Out:
# Confusion Matrix  [[5381    0]
#  [  16    0]]
#           Predicted
#          |   0  |   1  |
#          |------|------|
#        0 | 5381 |    0 |
# Actual   |------|------|
#        1 |   16 |    0 |
#          |------|------|

# %%
accuracy = (confusion_matrix[0, 0] + confusion_matrix[1, 1])/(confusion_matrix[0, 0] + confusion_matrix[1, 1]+confusion_matrix[0, 1]+confusion_matrix[1, 0])
print("Support Vector Machine")
print("-------------------------")
print("Mean accuracy with test data:", accuracy)
# Out:
# Support Vector Machine
# -------------------------
# Mean accuracy with test data: 0.997035390031499

# %% [markdown]
# ## 6. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
clf = LogisticRegression(random_state=0).fit(train_x, train_y)
ypredlog = clf.predict(train_x)
# Out:
# C:\Users\kaiwe\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
x_idx = np.arange(train_x.shape[0])

plt.plot(x_idx, ypredlog, 'mo', x_idx, train_y, 'b.',alpha=.3);
plt.title('Support Vector Machine, (0:dead, 1:survive) \
          \n Blue: actual data (ground truth), Red: predicted values');

# %%
predictlog_y = clf.predict(test_x)
confusion_matrix = metrics.confusion_matrix(test_y, predictlog_y)

print ("Confusion Matrix ", confusion_matrix)

print ("          Predicted")
print ("         |  0  |  1  |")
print ("         |-----|-----|")
print ("       0 | %3d | %3d |" % (confusion_matrix[0, 0],
                                   confusion_matrix[0, 1]))
print ("Actual   |-----|-----|")
print ("       1 | %3d | %3d |" % (confusion_matrix[1, 0],
                                   confusion_matrix[1, 1]))
print ("         |-----|-----|")
# Out:
# Confusion Matrix  [[5381    0]
#  [  16    0]]
#           Predicted
#          |  0  |  1  |
#          |-----|-----|
#        0 | 5381 |   0 |
# Actual   |-----|-----|
#        1 |  16 |   0 |
#          |-----|-----|

# %%
accuracy = metrics.accuracy_score(test_y, predictlog_y)
accuracy_percentage = 100 * accuracy
print("Logistic Regression")
print("-------------------------")
print("Accuracy:", accuracy_percentage)
# Out:
# Logistic Regression
# -------------------------
# Accuracy: 99.7035390031499
